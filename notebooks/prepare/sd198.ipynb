# %% [markdown]
# # Prepare SD-198 dataset for VLM training
#
# This notebook is inactive: **`data/datasets/sd-198/` is not in the current checkout.**
#
# Optional **experimental** resource if the SD-198 dump is added. The main study uses PAD-UFES-20; SD-198 is not required.
#
# Present sources: PAD, ISIC18, HC, Derm1M, MILK10K.

# %% [markdown]
# ## 1. Setup

# %%
from __future__ import annotations

import sys
from pathlib import Path

import pandas as pd

ROOT = Path.cwd()
while not (ROOT / "src").exists() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
if not (ROOT / "src").exists():
    raise FileNotFoundError(f"Could not find repo root (src/) from {Path.cwd()}")

sys.path.insert(0, str(ROOT / "src"))

from vlm_ft.data.prepare import require_source

CURRENT_SOURCES = "PAD, ISIC18, HC, Derm1M, MILK10K"

SD_ROOT = ROOT / "data/datasets/sd-198"
require_source(SD_ROOT, expected=CURRENT_SOURCES)
